# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder

# Sample dataset (list of transactions)
dataset =[
               ['Milk','Bread','Eggs'],
               ['Bread','Eggs','Butter'],
               ['Milk','Eggs'],
               ['Milk','Bread','Eggs','Butter'],
               ['Milk','Bread'],
               ['Milk','Eggs'],
               ['Milk','Bread','Butter'],
]

# Convert the dataset into a one-hot encoded format
te = TransactionEncoder()
te_ary = te.fit(dataset).transform(dataset)
df = pd.DataFrame(te_ary, columns=te.columns_)
print(df)
# Out:
#    Bread  Butter   Eggs   Milk
# 0   True   False   True   True
# 1   True    True   True  False
# 2  False   False   True   True
# 3   True    True   True   True
# 4   True   False  False   True
# 5  False   False   True   True
# 6   True    True  False   True

# %%
from mlxtend.frequent_patterns import apriori
# Define the minimum support threshold
min_support = 0.4
# Perform frequent itemset mining using Apriori
frequent_itemsets = apriori(df, min_support=min_support, use_colnames=True)
print(frequent_itemsets)
# Out:
#     support         itemsets
# 0  0.714286          (Bread)
# 1  0.428571         (Butter)
# 2  0.714286           (Eggs)
# 3  0.857143           (Milk)
# 4  0.428571  (Bread, Butter)
# 5  0.428571    (Eggs, Bread)
# 6  0.571429    (Bread, Milk)
# 7  0.571429     (Eggs, Milk)

# %%
min_support = 0.3
frequent_itemsets = apriori(df, min_support=min_support, use_colnames=True)
print(frequent_itemsets)
# Out:
#     support         itemsets
# 0  0.714286          (Bread)
# 1  0.428571         (Butter)
# 2  0.714286           (Eggs)
# 3  0.857143           (Milk)
# 4  0.428571  (Bread, Butter)
# 5  0.428571    (Eggs, Bread)
# 6  0.571429    (Bread, Milk)
# 7  0.571429     (Eggs, Milk)

# %%
min_support = 0.5
frequent_itemsets = apriori(df, min_support=min_support, use_colnames=True)
print(frequent_itemsets)
# Out:
#     support       itemsets
# 0  0.714286        (Bread)
# 1  0.714286         (Eggs)
# 2  0.857143         (Milk)
# 3  0.571429  (Bread, Milk)
# 4  0.571429   (Eggs, Milk)

# %%
min_support = 0.7
frequent_itemsets = apriori(df, min_support=min_support, use_colnames=True)
print(frequent_itemsets)
# Out:
#     support itemsets
# 0  0.714286  (Bread)
# 1  0.714286   (Eggs)
# 2  0.857143   (Milk)

# %%
min_support = 0.1
frequent_itemsets = apriori(df, min_support=min_support, use_colnames=True)
print(frequent_itemsets)
# Out:
#      support                     itemsets
# 0   0.714286                      (Bread)
# 1   0.428571                     (Butter)
# 2   0.714286                       (Eggs)
# 3   0.857143                       (Milk)
# 4   0.428571              (Bread, Butter)
# 5   0.428571                (Eggs, Bread)
# 6   0.571429                (Bread, Milk)
# 7   0.285714               (Eggs, Butter)
# 8   0.285714               (Milk, Butter)
# 9   0.571429                 (Eggs, Milk)
# 10  0.285714        (Eggs, Bread, Butter)
# 11  0.285714        (Bread, Milk, Butter)
# 12  0.285714          (Eggs, Bread, Milk)
# 13  0.142857         (Eggs, Milk, Butter)
# 14  0.142857  (Eggs, Bread, Milk, Butter)

# %%
from mlxtend.frequent_patterns import association_rules

# Generate association rules with minimum confidence threshold (e.g., 0.6)
min_confidence = 0.6
association_rules_df = association_rules(frequent_itemsets
, metric="confidence", min_threshold=min_confidence)
print("\nAssociation Rules:")
print(association_rules_df[['antecedents', 'consequents', 'support', 'confidence', 'lift']])
# Out:
# Association Rules:
#              antecedents    consequents   support  confidence      lift
# 0                (Bread)       (Butter)  0.428571    0.600000  1.400000
# 1               (Butter)        (Bread)  0.428571    1.000000  1.400000
# 2                 (Eggs)        (Bread)  0.428571    0.600000  0.840000
# 3                (Bread)         (Eggs)  0.428571    0.600000  0.840000
# 4                (Bread)         (Milk)  0.571429    0.800000  0.933333
# 5                 (Milk)        (Bread)  0.571429    0.666667  0.933333
# 6               (Butter)         (Eggs)  0.285714    0.666667  0.933333
# 7               (Butter)         (Milk)  0.285714    0.666667  0.777778
# 8                 (Eggs)         (Milk)  0.571429    0.800000  0.933333
# 9                 (Milk)         (Eggs)  0.571429    0.666667  0.933333
# 10         (Eggs, Bread)       (Butter)  0.285714    0.666667  1.555556
# 11        (Eggs, Butter)        (Bread)  0.285714    1.000000  1.400000
# 12       (Bread, Butter)         (Eggs)  0.285714    0.666667  0.933333
# 13              (Butter)  (Eggs, Bread)  0.285714    0.666667  1.555556
# 14       (Bread, Butter)         (Milk)  0.285714    0.666667  0.777778
# 15        (Milk, Butter)        (Bread)  0.285714    1.000000  1.400000
# 16              (Butter)  (Bread, Milk)  0.285714    0.666667  1.166667
# 17         (Eggs, Bread)         (Milk)  0.285714    0.666667  0.777778
# 18  (Eggs, Milk, Butter)        (Bread)  0.142857    1.000000  1.400000

# %%
min_confidence = 0.7
association_rules_df = association_rules(frequent_itemsets
, metric="confidence", min_threshold=min_confidence)
print("\nAssociation Rules:")
print(association_rules_df[['antecedents', 'consequents', 'support', 'confidence', 'lift']])
# Out:
# Association Rules:
#             antecedents consequents   support  confidence      lift
# 0              (Butter)     (Bread)  0.428571         1.0  1.400000
# 1               (Bread)      (Milk)  0.571429         0.8  0.933333
# 2                (Eggs)      (Milk)  0.571429         0.8  0.933333
# 3        (Eggs, Butter)     (Bread)  0.285714         1.0  1.400000
# 4        (Milk, Butter)     (Bread)  0.285714         1.0  1.400000
# 5  (Eggs, Milk, Butter)     (Bread)  0.142857         1.0  1.400000

# %%
min_support = 0.35
print(frequent_itemsets)
# Out:
#      support                     itemsets
# 0   0.714286                      (Bread)
# 1   0.428571                     (Butter)
# 2   0.714286                       (Eggs)
# 3   0.857143                       (Milk)
# 4   0.428571              (Bread, Butter)
# 5   0.428571                (Eggs, Bread)
# 6   0.571429                (Bread, Milk)
# 7   0.285714               (Eggs, Butter)
# 8   0.285714               (Milk, Butter)
# 9   0.571429                 (Eggs, Milk)
# 10  0.285714        (Eggs, Bread, Butter)
# 11  0.285714        (Bread, Milk, Butter)
# 12  0.285714          (Eggs, Bread, Milk)
# 13  0.142857         (Eggs, Milk, Butter)
# 14  0.142857  (Eggs, Bread, Milk, Butter)

# %%
import numpy as np
# Set a random seed for reproducibility
np.random.seed(42)
# Number of records (transactions) in the dataset
num_records = 1000
# Number of unique items in the grocery store
num_items = 10
# Generate the dummy dataset
transactions = []
for i in range(num_records):
    num_items_in_transaction = np.random.randint(1, num_items + 1)
    items = np.random.choice(range(1, num_items + 1)
    , num_items_in_transaction, replace=False)
    transactions.append([f"Item{item}" for item in items])
# Convert the dataset into a one-hot encoded format
te = TransactionEncoder()
te_ary = te.fit(transactions).transform(transactions)
df_encoded = pd.DataFrame(te_ary, columns=te.columns_)
print(df_encoded)
# Out:
#      Item1  Item10  Item2  Item3  Item4  Item5  Item6  Item7  Item8  Item9
# 0     True    True   True   True  False  False   True   True  False   True
# 1     True    True   True   True  False  False   True   True   True   True
# 2    False   False  False   True  False  False  False   True  False  False
# 3     True    True   True   True   True   True   True   True   True   True
# 4     True    True   True   True   True   True   True  False   True   True
# ..     ...     ...    ...    ...    ...    ...    ...    ...    ...    ...
# 995   True   False   True   True  False  False  False  False  False   True
# 996  False   False  False  False  False  False  False   True  False  False
# 997   True   False  False   True   True   True  False   True  False   True
# 998  False    True  False   True  False  False  False   True  False  False
# 999  False   False  False  False   True  False  False   True   True   True
#
# [1000 rows x 10 columns]

# %%
min_support = 0.2
frequent_itemsets = apriori(df_encoded, min_support=min_support, use_colnames=True)
print(frequent_itemsets)
# Out:
#      support                      itemsets
# 0      0.530                       (Item1)
# 1      0.546                      (Item10)
# 2      0.543                       (Item2)
# 3      0.545                       (Item3)
# 4      0.527                       (Item4)
# ..       ...                           ...
# 307    0.210  (Item7, Item8, Item6, Item5)
# 308    0.202  (Item7, Item9, Item5, Item6)
# 309    0.217  (Item8, Item9, Item5, Item6)
# 310    0.203  (Item7, Item8, Item9, Item5)
# 311    0.208  (Item7, Item8, Item9, Item6)
#
# [312 rows x 2 columns]

# %%
min_confidence = 0.67
association_rules_df = association_rules(frequent_itemsets, metric="confidence", min_threshold=min_confidence)
print("\nAssociation Rules:")
#print(association_rules_df[['antecedents', 'consequents', 'support', 'confidence', 'lift']])
print(association_rules_df)
# Out:
# Association Rules:
#                antecedents consequents  antecedent support  \
# 0                  (Item1)     (Item5)               0.530
# 1                  (Item4)     (Item3)               0.527
# 2                  (Item5)     (Item3)               0.540
# 3                  (Item7)     (Item3)               0.532
# 4                  (Item8)     (Item3)               0.533
# ..                     ...         ...                 ...
# 909  (Item8, Item9, Item5)     (Item7)               0.263
# 910  (Item7, Item8, Item9)     (Item6)               0.255
# 911  (Item7, Item8, Item6)     (Item9)               0.262
# 912  (Item7, Item9, Item6)     (Item8)               0.255
# 913  (Item8, Item9, Item6)     (Item7)               0.261
#
#      consequent support  support  confidence      lift  representativity  \
# 0                 0.540    0.358    0.675472  1.250874               1.0
# 1                 0.545    0.354    0.671727  1.232526               1.0
# 2                 0.545    0.362    0.670370  1.230037               1.0
# 3                 0.545    0.360    0.676692  1.241636               1.0
# 4                 0.545    0.362    0.679174  1.246192               1.0
# ..                  ...      ...         ...       ...               ...
# 909               0.532    0.203    0.771863  1.450871               1.0
# 910               0.533    0.208    0.815686  1.530368               1.0
# 911               0.545    0.208    0.793893  1.456685               1.0
# 912               0.533    0.208    0.815686  1.530368               1.0
# 913               0.532    0.208    0.796935  1.497998               1.0
#
#      leverage  conviction  zhangs_metric   jaccard  certainty  kulczynski
# 0    0.071800    1.417442       0.426721  0.502809   0.294504    0.669217
# 1    0.066785    1.386040       0.398855  0.493036   0.278520    0.660634
# 2    0.067700    1.380337       0.406558  0.500692   0.275539    0.667295
# 3    0.070060    1.407326       0.415836  0.502092   0.289432    0.668621
# 4    0.071515    1.418216       0.423031  0.505587   0.294889    0.671697
# ..        ...         ...            ...       ...        ...         ...
# 909  0.063084    2.051400       0.421653  0.342905   0.512528    0.576721
# 910  0.072085    2.533723       0.465185  0.358621   0.605324    0.602965
# 911  0.065210    2.207593       0.424810  0.347245   0.547018    0.587772
# 912  0.072085    2.533723       0.465185  0.358621   0.605324    0.602965
# 913  0.069148    2.304679       0.449854  0.355556   0.566100    0.593956
#
# [914 rows x 14 columns]

# %%
min_confidence = 0.6
association_rules_df = association_rules(frequent_itemsets
, metric="confidence", min_threshold=min_confidence)
print("\nAssociation Rules:")
print(association_rules_df[['antecedents', 'consequents', 'support', 'confidence', 'lift']])
# Out:
# Association Rules:
#                 antecedents     consequents  support  confidence      lift
# 0                  (Item10)         (Item1)    0.347    0.635531  1.199115
# 1                   (Item1)        (Item10)    0.347    0.654717  1.199115
# 2                   (Item2)         (Item1)    0.339    0.624309  1.177942
# 3                   (Item1)         (Item2)    0.339    0.639623  1.177942
# 4                   (Item3)         (Item1)    0.348    0.638532  1.204778
# ...                     ...             ...      ...         ...       ...
# 1197  (Item7, Item8, Item6)         (Item9)    0.208    0.793893  1.456685
# 1198  (Item7, Item9, Item6)         (Item8)    0.208    0.815686  1.530368
# 1199  (Item8, Item9, Item6)         (Item7)    0.208    0.796935  1.497998
# 1200         (Item7, Item6)  (Item8, Item9)    0.208    0.609971  1.718227
# 1201         (Item9, Item6)  (Item7, Item8)    0.208    0.601156  1.732438
#
# [1202 rows x 5 columns]

# %%
min_confidence = 0.8
association_rules_df = association_rules(frequent_itemsets
, metric="confidence", min_threshold=min_confidence)
print("\nAssociation Rules:")  
print(association_rules_df[['antecedents', 'consequents', 'support', 'confidence', 'lift']])
# Out:
# Association Rules:
#                 antecedents consequents  support  confidence      lift
# 0     (Item3, Item2, Item1)    (Item10)    0.205    0.820000  1.501832
# 1    (Item2, Item1, Item10)     (Item3)    0.205    0.810277  1.486746
# 2    (Item8, Item1, Item10)     (Item2)    0.201    0.810484  1.492604
# 3     (Item9, Item2, Item1)    (Item10)    0.206    0.824000  1.509158
# 4    (Item2, Item1, Item10)     (Item9)    0.206    0.814229  1.493999
# ..                      ...         ...      ...         ...       ...
# 221   (Item8, Item9, Item6)     (Item5)    0.217    0.831418  1.539662
# 222   (Item8, Item6, Item5)     (Item9)    0.217    0.800738  1.469244
# 223   (Item9, Item5, Item6)     (Item8)    0.217    0.825095  1.548021
# 224   (Item7, Item8, Item9)     (Item6)    0.208    0.815686  1.530368
# 225   (Item7, Item9, Item6)     (Item8)    0.208    0.815686  1.530368
#
# [226 rows x 5 columns]
