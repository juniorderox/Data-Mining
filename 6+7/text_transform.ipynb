# %%
s = """Three Rings for the Elven-kings under the sky,
Seven for the Dwarf-lords in halls of stone,
Nine for Mortal Men, doomed to die,
One for the Dark Lord on his dark throne
In the Land of Mordor where the Shadows lie.
One Ring to rule them all, One Ring to find them,
One Ring to bring them all and in the darkness bind them.
In the Land of Mordor where the Shadows lie. """.lower()
words = s.split()
from collections import Counter
c = Counter(words)
print(c)
# Out:
# Counter({'the': 9, 'for': 4, 'in': 4, 'to': 4, 'one': 4, 'of': 3, 'ring': 3, 'dark': 2, 'land': 2, 'mordor': 2, 'where': 2, 'shadows': 2, 'lie.': 2, 'them': 2, 'three': 1, 'rings': 1, 'elven-kings': 1, 'under': 1, 'sky,': 1, 'seven': 1, 'dwarf-lords': 1, 'halls': 1, 'stone,': 1, 'nine': 1, 'mortal': 1, 'men,': 1, 'doomed': 1, 'die,': 1, 'lord': 1, 'on': 1, 'his': 1, 'throne': 1, 'rule': 1, 'all,': 1, 'find': 1, 'them,': 1, 'bring': 1, 'all': 1, 'and': 1, 'darkness': 1, 'bind': 1, 'them.': 1})

# %%
c.most_common(7)
# Out:
# [('the', 9),
#  ('for', 4),
#  ('in', 4),
#  ('to', 4),
#  ('one', 4),
#  ('of', 3),
#  ('ring', 3)]

# %%
import json
import re
with open("tweets.json", "r", encoding="utf-8") as f:
    data = json.load(f)

# Extract text fields
texts = [item["text"] for item in data["data"]]
print(texts[:3])  # Print first 3 tweets for verification
# Out:
# ['The European Union is not DEMOcracy – rule of the people – but rather BUREAUcracy – rule of the unelected bureaucrat!', 'As a person in the Cybersecurity field, what would be your first response to this ? https://t.co/hnIxlQCBgm', "Congrats to our final 5 nominees for #TheGameAwards Players' Voice, a 100% fan voted award.\n\nClair Obscur: Expedition 33\nDispatch\nGenshin Impact\nHollow Knight: Sliksong\nWuthering Waves\n\nVote now to select the winner: https://t.co/nxnogzsAdO https://t.co/GpUKmuUYIO"]

# %%
for word, count in c.most_common(10):
    print(f"{word}: {count}")
# Out:
# the: 18
# https: 13
# t: 13
# co: 13
# of: 9
# to: 8
# and: 7
# in: 6
# for: 5
# her: 5
